# %% [markdown]
# ## BERT для вопросно-ответных систем
#
# Стандартный датасет для тренировки QA моделей (или question-answering моделей) называется **SQUAD**[2] и расшифровывается как Stanford Question Answering Dataset.
#
# Он включает в себя вопросы и ответы на них по достаточно разнообразной тематике.
# - Вопросы формировались на основе статей или отрывков из статьи из Википедии.
# - Ответ на каждый вопрос представляет собой сегмент текста или промежуток из соответствующего отрывка.
# - В новой версии датасета (в 2.0 версии) даже возможны вопросы без ответа.
#   - Имеется в виду, что есть вопросы, для ответа на которые недостаточно информации в предложенном фрагменте текста.
#
# Таким образом, алгоритм составления этого датасета был следующим.
# - Асессор читал фрагмент текста из Википедии (как правило, всего несколько абзацев),
# - формулировал вопрос по прочитанному и фиксировал правильный ответ.
#
# На большинство вопросов присутствует несколько вариантов ответа. Но, как правило, это всего лишь переформулировки одного и того же, по смыслу, варианта ответа.
#
# Например, на вопрос "когда началась эпоха Возрождения в Италии" можно ответить "14 век", "в 14 веке", "в начале 14 века" или как-то ещё, использовав слова "14" и "век".
#
# Учитывая специфику нашего датасета, на вход нейросети мы будем подавать не только сам вопрос, но и соответствующий фрагмент текста, параграф текста. А в качестве выхода нейросети будем ожидать две позиции в тексте: начало ответа и конец ответа.
#
#
# [1] https://stepik.org/lesson/268748/step/7?unit=249768
# [2] https://rajpurkar.github.io/SQuAD-explorer/

# %%
# Если Вы запускаете ноутбук на colab или kaggle,
# выполните следующие строчки, чтобы подгрузить библиотеку dlnlputils:

# !git clone https://github.com/Samsung-IT-Academy/stepik-dl-nlp.git && pip install -r stepik-dl-nlp/requirements.txt
# import sys; sys.path.append('./stepik-dl-nlp')

# %% [markdown]
# Скачайте датасет (SQuAD) [отсюда](https://rajpurkar.github.io/SQuAD-explorer/). Для выполенения семинара Вам понадобятся файлы `train-v2.0.json` и `dev-v2.0.json`.

# %% [markdown]
# Склонируйте репозиторий https://github.com/huggingface/transformers (воспользуйтесь скриптом `clone_pytorch_transformers.sh`) и положите путь до папки `examples` в переменную `PATH_TO_EXAMPLES`.

# %%
import os

PATH_TO_TRANSFORMERS_REPO = '../transformers/'
os.environ['PATH_TO_TRANSFORMER_REPO'] = PATH_TO_TRANSFORMERS_REPO

# %%
# ! wget https://raw.githubusercontent.com/Samsung-IT-Academy/stepik-dl-nlp/master/clone_pytorch_transformers.sh
# ! bash clone_pytorch_transformers.sh $PATH_TO_TRANSFORMERS_REPO

# %% [markdown]
# Мы клоновали древнюю версию `transformers` и хотим использовать ее вместо уже установленного пакета.
# При запуске питон окружения пути для поиска модулей собираются в `sys.path`  в следующем порядке (поиск модулей также будет идти в этом порядке):
# 1. Домашний каталог программы.
# 2. Каталоги PYTHONPATH (если установлены).
#    - в уже запущенном окружении переустанавливать для данного окружения смысла уже нет (в `sys.path` не попадет)
# 3. Каталоги стандартной библиотеки.
# 4. Содержимое любых файлов .pth (при их наличии).
# 5. Подкаталог site-packages, где размещаются сторонние расширения.

# %%
import sys

sys.path, os.environ.get('PYTHONPATH', None)
# Out:
# (['/mnt/INT_STORAGE/PYTHON/projects/stepik.org/DataScience/Нейронные сети и обработка текста/stepik-dl-nlp',
#   '/usr/local/lib/python39.zip',
#   '/usr/local/lib/python3.9',
#   '/usr/local/lib/python3.9/lib-dynload',
#   '',
#   '/home/user1/envs/py39/lib/python3.9/site-packages',
#   '/home/user1/envs/py39/lib/python3.9/site-packages/torchtext-0.11.0a0-py3.9-linux-x86_64.egg',
#   '/home/user1/envs/py39/lib/python3.9/site-packages/torchaudio-0.10.1+6f539cf-py3.9-linux-x86_64.egg',
#   '/home/user1/.local/lib/python3.9/site-packages'],
#  None)

# %% [markdown]
# Аппендить в `sys.path` при уже установленном пакете тоже нет смысла, т.к. каталоги пакетов будут раньше, и питон найдет этот модуль там.

# %%
import sys

PATH_TO_EXAMPLES = os.path.join(PATH_TO_TRANSFORMERS_REPO, 'examples')

sys.path.insert(1, PATH_TO_EXAMPLES)
sys.path.insert(1, PATH_TO_TRANSFORMERS_REPO)

# %% [markdown]
# # Импорт модулей

# %%
import torch
import tqdm
import json

from utils_squad import (read_squad_examples, convert_examples_to_features,
                         RawResult, write_predictions,
                         RawResultExtended, write_predictions_extended)

from run_squad import train, load_and_cache_examples

from torch.utils.data import (DataLoader, RandomSampler, SequentialSampler, TensorDataset)

from transformers import (WEIGHTS_NAME, BertConfig, XLNetConfig, XLMConfig,
                          BertForQuestionAnswering, BertTokenizer)

from utils_squad_evaluate import EVAL_OPTS, main as evaluate_on_squad

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Готовые токенайзер и модель

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True, do_basic_tokenize=True)
model = BertForQuestionAnswering.from_pretrained('bert-base-uncased')

# %%
# если Вы не хотите запускать файн-тюнинг, пропустите блок "Дообучение",
# подгрузите веса уже дообученной модели и переходите к блоку "Оценка качества"

# скачайте веса с Google-диска и положите их в папку models
# https://drive.google.com/drive/folders/1-DR30q7MF-gZ51TDx596dAOhgh-uOAPj?usp=sharing

# %%
if torch.cuda.is_available():
    model.cuda()
    model.load_state_dict(torch.load('models/bert_squad_1epoch.pt')) # если у вас есть GPU
else:
    model.load_state_dict(torch.load('models/bert_squad_1epoch.pt', map_location=device)) # если GPU нет

# %% [markdown]
# ### Дообучение
#
# - ~7 часов на 5 эпох
#
# В класс "train_opts" выписаны ВСЕ параметры, на которые стоит обратить внимание перед запуском модели.

# %%
# !pip install dataclasses
from dataclasses import dataclass

@dataclass
class TRAIN_OPTS:
    train_file : str = './datasets/SQUAD/train-v2.0.json'    # SQuAD json-файл для обучения
    predict_file : str = './datasets/SQUAD/dev-v2.0.json'    # SQuAD json-файл для тестирования
    model_type : str = 'bert'               # тип модели (может быть  'bert', 'xlnet', 'xlm', 'distilbert')
    model_name_or_path : str = 'bert-base-uncased' # путь до предобученной модели или название модели из ALL_MODELS
    output_dir : str = '/tmp' # путь до директории, где будут храниться чекпоинты и предсказания модели
    device : str = 'cuda' # cuda или cpu
    n_gpu : int = 1 # количество gpu для обучения
    cache_dir : str = '' # где хранить предобученные модели, загруженные с s3
        
    # Если true, то в датасет будут включены вопросы, на которые нет ответов.
    version_2_with_negative : bool = True
    # Если (null_score - best_non_null) больше, чем порог, предсказывать null.
    null_score_diff_threshold : float = 0.0
    # Максимальная длина входной последовательности после WordPiece токенизации. Sequences 
    # Последовательности длиннее будут укорочены, для более коротких последовательностей будет использован паддинг
    max_seq_length : int = 384
    # Сколько stride использовать при делении длинного документа на чанки
    doc_stride : int = 128
    # Максимальное количество токенов в вопросе. Более длинные вопросы будут укорочены до этой длины
    max_query_length : int = 128 #
        
    do_train : bool = True
    do_eval : bool = True
        
    # Запускать ли evaluation на каждом logging_step
    evaluate_during_training : bool = True
    # Должно быть True, если Вы используете uncased модели
    do_lower_case : bool = True #
    
    per_gpu_train_batch_size : int = 8 # размер батча для обучения
    per_gpu_eval_batch_size : int = 8 # размер батча для eval
    learning_rate : float = 5e-5 # learning rate
    gradient_accumulation_steps : int = 1 # количество шагов, которые нужно сделать перед backward/update pass
    weight_decay : float = 0.0 # weight decay
    adam_epsilon : float = 1e-8 # эпсилон для Adam
    max_grad_norm : float = 1.0 # максимальная норма градиента
    num_train_epochs : float = 5.0 # количество эпох на обучение
    max_steps : int = -1 # общее количество шагов на обучение (override num_train_epochs)
    warmup_steps : int = 0 # warmup 
    n_best_size : int = 5 # количество ответов, которые надо сгенерировать для записи в nbest_predictions.json
    max_answer_length : int = 30 # максимально возможная длина ответа
    verbose_logging : bool = True # печатать или нет warnings, относящиеся к обработке данных
    logging_steps : int = 5000 # логировать каждые X шагов
    save_steps : int = 5000 # сохранять чекпоинт каждые X шагов
        
    # Evaluate all checkpoints starting with the same prefix as model_name ending and ending with step number
    eval_all_checkpoints : bool = True
    no_cuda : bool = False # не использовать CUDA
    overwrite_output_dir : bool = True # переписывать ли содержимое директории с выходными файлами
    overwrite_cache : bool = True # переписывать ли закешированные данные для обучения и evaluation
    seed : int = 42 # random seed
    local_rank : int = -1 # local rank для распределенного обучения на GPU
    fp16 : bool = False # использовать ли 16-bit (mixed) precision (через NVIDIA apex) вместо 32-bit"
    # Apex AMP optimization level: ['O0', 'O1', 'O2', and 'O3'].
    # Подробнее тут: https://nvidia.github.io/apex/amp.html
    fp16_opt_level : str = '01'

# %% [markdown]
# Все варианты моделей, с которыми мы можем работать с помощью библиотеки pytorch-transformers

# %%
ALL_MODELS = sum((tuple(conf.pretrained_config_archive_map.keys()) \
                  for conf in (BertConfig, XLNetConfig, XLMConfig)), ())
ALL_MODELS
# Out:
# ('bert-base-uncased',
#  'bert-large-uncased',
#  'bert-base-cased',
#  'bert-large-cased',
#  'bert-base-multilingual-uncased',
#  'bert-base-multilingual-cased',
#  'bert-base-chinese',
#  'bert-base-german-cased',
#  'bert-large-uncased-whole-word-masking',
#  'bert-large-cased-whole-word-masking',
#  'bert-large-uncased-whole-word-masking-finetuned-squad',
#  'bert-large-cased-whole-word-masking-finetuned-squad',
#  'bert-base-cased-finetuned-mrpc',
#  'bert-base-german-dbmdz-cased',
#  'bert-base-german-dbmdz-uncased',
#  'xlnet-base-cased',
#  'xlnet-large-cased',
#  'xlm-mlm-en-2048',
#  'xlm-mlm-ende-1024',
#  'xlm-mlm-enfr-1024',
#  'xlm-mlm-enro-1024',
#  'xlm-mlm-tlm-xnli15-1024',
#  'xlm-mlm-xnli15-1024',
#  'xlm-clm-enfr-1024',
#  'xlm-clm-ende-1024',
#  'xlm-mlm-17-1280',
#  'xlm-mlm-100-1280')

# %%
# args = TRAIN_OPTS()
# train_dataset = load_and_cache_examples(args, tokenizer, evaluate=False, output_examples=False)

# %%
# train(args, train_dataset, model, tokenizer)

# %% [markdown]
# Сохраняем веса дообученной модели на диск, чтобы в следующий раз не обучать модель заново.

# %%
# torch.save(model.state_dict(), 'models/bert_squad_final_5epoch.pt')

# %% [markdown]
# Подгрузить веса модели можно так:

# %%
# model.load_state_dict(torch.load('models/bert_squad_5epochs.pt'))

# %% [markdown]
# # Оценка качества работы модели

# %% [markdown]
# Выделим подмножество вопросов, чтобы быстрее считалось

# %%
PATH_TO_DEV_SQUAD = './datasets/SQUAD/dev-v2.0.json'
PATH_TO_SMALL_DEV_SQUAD = './datasets/SQUAD/small_dev-v2.0.json'

with open(PATH_TO_DEV_SQUAD, 'r') as iofile:
    full_sample = json.load(iofile)
    
small_sample = {
    'version': full_sample['version'],
    'data': full_sample['data'][:1]
}

with open(PATH_TO_SMALL_DEV_SQUAD, 'w') as iofile:
    json.dump(small_sample, iofile)

# %% [markdown]
# Параметры, которые нам будут нужны для evaluation

# %%
max_seq_length = 384
outside_pos = max_seq_length + 10
doc_stride = 128
max_query_length = 64
max_answer_length = 30

# %% [markdown]
# - Грузим малую выборку
# - Конвертируем в признаки (используем тот же токенайзер, что при обучении)
# - Вытаскиваем из признаков нужные переменные (похожи на те, что в классификации предложений)
#   - input_ids номера токенов
#   - input_mask 1/0 = токен/паддинг
#   - cls_index индекс классификационного токена
#   - p_mask 1 - токены, которых не может быть в ответе, 0 - могут быть в ответе

# %%
examples = read_squad_examples(
    input_file=PATH_TO_SMALL_DEV_SQUAD,
    is_training=False,
    version_2_with_negative=True)

features = convert_examples_to_features(
    examples=examples,
    tokenizer=tokenizer,
    max_seq_length=max_seq_length,
    doc_stride=doc_stride,
    max_query_length=max_query_length,
    is_training=False,
    cls_token_segment_id=0,
    pad_token_segment_id=0,
    cls_token_at_end=False
)

input_ids = torch.tensor([f.input_ids for f in features], dtype=torch.long)
input_mask = torch.tensor([f.input_mask for f in features], dtype=torch.long)
segment_ids = torch.tensor([f.segment_ids for f in features], dtype=torch.long)
cls_index = torch.tensor([f.cls_index for f in features], dtype=torch.long)
p_mask = torch.tensor([f.p_mask for f in features], dtype=torch.float)

example_index = torch.arange(input_ids.size(0), dtype=torch.long)
dataset = TensorDataset(input_ids, input_mask, segment_ids, example_index, cls_index, p_mask)
# Out:
# 100%|██████████| 208/208 [00:01<00:00, 135.44it/s]

# %% [markdown]
# Создаем их них объект `DataLoader`

# %%
eval_sampler = SequentialSampler(dataset)
eval_dataloader = DataLoader(dataset, sampler=eval_sampler, batch_size=8)

# %% [markdown]
# Просчет модели
# - распаковываем батч на переменные и передаём полученные данные в нашу модель, чтобы получить предсказание модели
# - ответ модели собираем в `all_results`

# %%
from tqdm.notebook import tqdm  # !pip install ipywidgets; jupyter nbextension enable --py widgetsnbextension

def to_list(tensor):
    return tensor.detach().cpu().tolist()

all_results = []
for idx, batch in enumerate(tqdm(eval_dataloader, desc="Evaluating")):
    model.eval()
    batch = tuple(t.to(device) for t in batch)
    with torch.no_grad():
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1]
                  }
        inputs['token_type_ids'] = batch[2]
        example_indices = batch[3]
        outputs = model(**inputs)

    for i, example_index in enumerate(example_indices):
        eval_feature = features[example_index.item()]
        unique_id = int(eval_feature.unique_id)
        result = RawResult(unique_id    = unique_id,
                           start_logits = to_list(outputs[0][i]),
                           end_logits   = to_list(outputs[1][i]))
        all_results.append(result)
# Out:
# Evaluating:   0%|          | 0/27 [00:00<?, ?it/s]

# %%
all_results[0].unique_id, all_results[0].start_logits[:5], all_results[0].end_logits[:5]
# Out:
# (1000000000,
#  [0.5573755502700806,
#   -5.768959045410156,
#   -4.9304986000061035,
#   -6.4673590660095215,
#   -8.117743492126465],
#  [0.7398626208305359,
#   -8.749387741088867,
#   -5.381954669952393,
#   -6.655617713928223,
#   -8.192229270935059])

# %% [markdown]
# Сформируем читабельный ответ из аппроксимации модели

# %%
n_best_size = 5
do_lower_case = True
output_prediction_file = './results/output_1best_file'
output_nbest_file = './results/output_nbest_file'
output_na_prob_file = './results/output_na_prob_file'
verbose_logging = True
version_2_with_negative = True
null_score_diff_threshold = 0.0

# %%
# Генерируем файл с n лучшими ответами `output_nbest_file`
write_predictions(examples, features, all_results, n_best_size,
                    max_answer_length, do_lower_case, output_prediction_file,
                    output_nbest_file, output_na_prob_file, verbose_logging,
                    version_2_with_negative, null_score_diff_threshold)
pass

# %% [markdown]
# `EVAL_OPTS` — по структуре оно очень похоже на класс `TRAIN_OPTS`
#
# Считаем метрики используя официальный SQuAD script[1]
#
# [1] https://rajpurkar.github.io/SQuAD-explorer/

# %%
# Считаем метрики используя официальный SQuAD script
evaluate_options = EVAL_OPTS(data_file=PATH_TO_SMALL_DEV_SQUAD,
                             pred_file=output_prediction_file,
                             na_prob_file=output_na_prob_file)
results = evaluate_on_squad(evaluate_options)
# Out:
# {
#   "exact": 68.26923076923077,
#   "f1": 71.22710622710623,
#   "total": 208,
#   "HasAns_exact": 76.04166666666667,
#   "HasAns_f1": 82.45039682539682,
#   "HasAns_total": 96,
#   "NoAns_exact": 61.607142857142854,
#   "NoAns_f1": 61.607142857142854,
#   "NoAns_total": 112,
#   "best_exact": 72.59615384615384,
#   "best_exact_thresh": -5.180886268615723,
#   "best_f1": 74.75274725274724,
#   "best_f1_thresh": -2.038421154022217
# }

# %% [markdown]
# Посмотрим глазами на вопросы и предсказанные БЕРТом ответы:

# %%
with open('./results/output_nbest_file', 'r') as iofile:
    predicted_answers = json.load(iofile)

# %%
questions = {}
for paragraph in small_sample['data'][0]['paragraphs']:
    for question in paragraph['qas']:
        questions[question['id']] = {
            'question': question['question'],
            'answers': question['answers'],
            'paragraph': paragraph['context']
        }

# %%
for q_num, (key, data) in enumerate(predicted_answers.items()):
    gt = '' if len(questions[key]['answers']) == 0 else questions[key]['answers'][0]['text']
    print('Вопрос {0}:'.format(q_num+1), questions[key]['question'])
    print('-----------------------------------')
    print('Ground truth:', gt)
    print('-----------------------------------')   
    print('Ответы, предсказанные БЕРТом:')
    preds = ['{0}) '.format(ans_num + 1) + answer['text'] + \
             ' (уверенность {0:.2f}%)'.format(answer['probability']*100) \
             for ans_num, answer in enumerate(data)]
    print('\n'.join(preds))
#     print('-----------------------------------')   
#     print('Параграф:', questions[key]['paragraph'])
    print('\n\n')
# Out:
# Вопрос 1: In what country is Normandy located?
# -----------------------------------
# Ground truth: France
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) France (уверенность 99.22%)
# 2) a region in France (уверенность 0.37%)
# 3) France. (уверенность 0.15%)
# 4) region in France (уверенность 0.14%)
# 5) France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway (уверенность 0.12%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 2: When were the Normans in Normandy?
# -----------------------------------
# Ground truth: 10th and 11th centuries
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 10th and 11th centuries (уверенность 44.30%)
# 2) in the 10th and 11th centuries (уверенность 29.12%)
# 3) the 10th and 11th centuries (уверенность 25.49%)
# 4) 11th centuries (уверенность 0.83%)
# 5) 10th and 11th (уверенность 0.25%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 3: From which countries did the Norse originate?
# -----------------------------------
# Ground truth: Denmark, Iceland and Norway
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Denmark, Iceland and Norway (уверенность 90.22%)
# 2)  (уверенность 4.40%)
# 3) Iceland and Norway (уверенность 2.79%)
# 4) Denmark, Iceland (уверенность 1.41%)
# 5) Denmark (уверенность 1.18%)
#
#
#
# Вопрос 4: Who was the Norse leader?
# -----------------------------------
# Ground truth: Rollo
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Rollo (уверенность 99.25%)
# 2) leader Rollo (уверенность 0.32%)
# 3) Rollo, (уверенность 0.27%)
# 4) Rollo, agreed to swear fealty to King Charles III (уверенность 0.08%)
# 5) their leader Rollo (уверенность 0.05%)
# 6)  (уверенность 0.03%)
#
#
#
# Вопрос 5: What century did the Normans first gain their separate identity?
# -----------------------------------
# Ground truth: 10th century
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 10th (уверенность 63.91%)
# 2) 10th century (уверенность 30.01%)
# 3) the 10th (уверенность 2.72%)
# 4) the first half of the 10th (уверенность 1.87%)
# 5) first half of the 10th (уверенность 1.46%)
# 6)  (уверенность 0.02%)
#
#
#
# Вопрос 6: Who gave their name to Normandy in the 1000's and 1100's
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.86%)
# 2) Normans (уверенность 0.06%)
# 3) The Normans (уверенность 0.06%)
# 4) Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries (уверенность 0.01%)
# 5) Normans (Norman: Nourmands; French: Normands; Latin: Normanni) (уверенность 0.00%)
#
#
#
# Вопрос 7: What is France a region of?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 52.81%)
# 2) Normandy (уверенность 41.04%)
# 3) Normandy, a region in France. (уверенность 3.29%)
# 4) Normandy, a region in France (уверенность 2.69%)
# 5) Normans (уверенность 0.17%)
#
#
#
# Вопрос 8: Who did King Charles III swear fealty to?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) West Francia (уверенность 93.61%)
# 2) of West Francia (уверенность 5.66%)
# 3) West Francia. (уверенность 0.60%)
# 4)  (уверенность 0.08%)
# 5) Normans (уверенность 0.04%)
#
#
#
# Вопрос 9: When did the Frankish identity emerge?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.71%)
# 2) first half of the 10th century (уверенность 0.08%)
# 3) 10th century (уверенность 0.08%)
# 4) the first half of the 10th century (уверенность 0.07%)
# 5) in the first half of the 10th century (уверенность 0.06%)
#
#
#
# Вопрос 10: Who was the duke in the battle of Hastings?
# -----------------------------------
# Ground truth: William the Conqueror
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) William the Conqueror (уверенность 99.35%)
# 2) Conqueror (уверенность 0.17%)
# 3) the Conqueror (уверенность 0.17%)
# 4) William the Conqueror, (уверенность 0.16%)
# 5) William (уверенность 0.14%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 11: Who ruled the duchy of Normandy
# -----------------------------------
# Ground truth: Richard I
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Richard I of Normandy (уверенность 54.85%)
# 2) Richard I (уверенность 41.58%)
# 3) under Richard I of Normandy (уверенность 1.43%)
# 4) under Richard I (уверенность 1.08%)
# 5) The Duchy of Normandy, which they formed by treaty with the French crown, was a great fief of medieval France, and under Richard I of Normandy (уверенность 1.06%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 12: What religion were the Normans
# -----------------------------------
# Ground truth: Catholic
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Catholic orthodoxy (уверенность 43.56%)
# 2) Christian piety, becoming exponents of the Catholic orthodoxy (уверенность 33.58%)
# 3) the Catholic orthodoxy (уверенность 10.20%)
# 4) Christian (уверенность 6.37%)
# 5) The Normans were famed for their martial spirit and eventually for their Christian piety, becoming exponents of the Catholic orthodoxy (уверенность 6.29%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 13: What type of major impact did the Norman dynasty have on modern Europe?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) political, cultural and military (уверенность 79.89%)
# 2) political, cultural and military impact (уверенность 10.65%)
# 3) political (уверенность 3.47%)
# 4) cultural and military (уверенность 3.07%)
# 5) political, cultural (уверенность 2.89%)
# 6)  (уверенность 0.02%)
#
#
#
# Вопрос 14: Who was famed for their Christian spirit?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 97.28%)
# 2) The Normans (уверенность 1.79%)
# 3) Normans (уверенность 0.84%)
# 4) Norman dynasty had a major political, cultural and military impact on medieval Europe and even the Near East. The Normans (уверенность 0.05%)
# 5) The Normans were famed for their martial spirit and eventually for their Christian piety, (уверенность 0.04%)
#
#
#
# Вопрос 15: Who assimilted the Roman language?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 100.00%)
# 2) The Normans (уверенность 0.00%)
# 3) Normans (уверенность 0.00%)
# 4) The Norman dynasty had a major political, cultural and military impact on medieval Europe and even the Near East. The Normans (уверенность 0.00%)
# 5) Norman dynasty had a major political, cultural and military impact on medieval Europe and even the Near East. The Normans (уверенность 0.00%)
#
#
#
# Вопрос 16: Who ruled the country of Normandy?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Richard I (уверенность 85.65%)
# 2) Richard I of Normandy (уверенность 13.56%)
# 3) under Richard I (уверенность 0.35%)
# 4) medieval France, and under Richard I (уверенность 0.25%)
# 5) France, and under Richard I (уверенность 0.19%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 17: What principality did William the conquerer found?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 79.05%)
# 2) Antioch (уверенность 9.64%)
# 3) Principality of Antioch (уверенность 8.42%)
# 4) the Principality of Antioch (уверенность 2.76%)
# 5) England (уверенность 0.12%)
#
#
#
# Вопрос 18: What is the original meaning of the word Norman?
# -----------------------------------
# Ground truth: Viking
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Normant (уверенность 32.29%)
# 2) Normant, modern French normand (уверенность 25.64%)
# 3) Normans/Normanz, plural of Normant (уверенность 16.78%)
# 4) Normans/Normanz, plural of Normant, modern French normand (уверенность 13.32%)
# 5) normand (уверенность 10.86%)
# 6)  (уверенность 1.11%)
#
#
#
# Вопрос 19: When was the Latin version of the word Norman first recorded?
# -----------------------------------
# Ground truth: 9th century
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 9th century (уверенность 90.05%)
# 2) Medieval Latin, 9th century (уверенность 3.53%)
# 3) 9th century) (уверенность 3.37%)
# 4) 9th (уверенность 2.52%)
# 5) , 9th century (уверенность 0.52%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 20: What name comes from the English words Normans/Normanz?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.96%)
# 2) Normans (уверенность 0.03%)
# 3) Normans" comes from the French words Normans/Normanz, plural of Normant, modern French normand (уверенность 0.01%)
# 4) Normans" comes from the French words Normans/Normanz, plural of Normant (уверенность 0.00%)
# 5) "Normans (уверенность 0.00%)
#
#
#
# Вопрос 21: When was the French version of the word Norman first recorded?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 95.14%)
# 2) Medieval Latin, 9th century (уверенность 1.85%)
# 3) 9th century (уверенность 1.58%)
# 4) in Medieval Latin, 9th century (уверенность 1.27%)
# 5) Medieval Latin (уверенность 0.16%)
#
#
#
# Вопрос 22: When was the Duchy of Normandy founded?
# -----------------------------------
# Ground truth: 911
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 911 (уверенность 93.65%)
# 2) in 911 (уверенность 3.40%)
# 3) began in 911 (уверенность 1.47%)
# 4) 911 as a fiefdom, was established by the treaty of Saint-Clair-sur-Epte (уверенность 1.15%)
# 5) 911 as a fiefdom, (уверенность 0.31%)
# 6)  (уверенность 0.02%)
#
#
#
# Вопрос 23: Who did Rollo sign the treaty of Saint-Clair-sur-Epte with?
# -----------------------------------
# Ground truth: King Charles III
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) King Charles III of West Francia (уверенность 40.01%)
# 2) King Charles III (уверенность 19.34%)
# 3) King Charles III of West Francia and the famed Viking ruler Rollo (уверенность 19.10%)
# 4) Charles III of West Francia (уверенность 12.50%)
# 5) Charles III (уверенность 6.04%)
# 6)  (уверенность 3.01%)
#
#
#
# Вопрос 24: What river originally bounded the Duchy
# -----------------------------------
# Ground truth: Seine
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) river Seine (уверенность 74.18%)
# 2)  (уверенность 12.67%)
# 3) the river Seine (уверенность 11.43%)
# 4) river Seine, but the Duchy would eventually extend west beyond the Seine (уверенность 1.50%)
# 5) the river Seine, but the Duchy would eventually extend west beyond the Seine (уверенность 0.23%)
#
#
#
# Вопрос 25: when did Nors encampments ivolve into destructive incursions?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 10th century (уверенность 32.65%)
# 2) course of the 10th century (уверенность 28.57%)
# 3) In the course of the 10th century (уверенность 19.16%)
# 4) the 10th century (уверенность 13.85%)
# 5)  (уверенность 5.77%)
#
#
#
# Вопрос 26: What treaty was established in the 9th century?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.51%)
# 2) treaty of Saint-Clair-sur-Epte (уверенность 0.34%)
# 3) the treaty of Saint-Clair-sur-Epte (уверенность 0.09%)
# 4) The Duchy of Normandy, which began in 911 as a fiefdom, was established by the treaty of Saint-Clair-sur-Epte (уверенность 0.04%)
# 5) Duchy of Normandy, which began in 911 as a fiefdom, was established by the treaty of Saint-Clair-sur-Epte (уверенность 0.02%)
#
#
#
# Вопрос 27: Who established a treaty with King Charles the third of France?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.52%)
# 2) King Charles III of West Francia and the famed Viking ruler Rollo (уверенность 0.16%)
# 3) King Charles III of West Francia (уверенность 0.12%)
# 4) Charles III of West Francia and the famed Viking ruler Rollo (уверенность 0.11%)
# 5) Charles III of West Francia (уверенность 0.08%)
#
#
#
# Вопрос 28: What did the French promises to protect Rollo and his men from?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) further Viking incursions (уверенность 63.75%)
# 2) Viking incursions (уверенность 32.87%)
# 3) against further Viking incursions (уверенность 1.60%)
# 4) their protection against further Viking incursions (уверенность 1.24%)
# 5) further Viking (уверенность 0.45%)
# 6)  (уверенность 0.09%)
#
#
#
# Вопрос 29: Who upon arriving gave the original viking settlers a common identity?
# -----------------------------------
# Ground truth: Rollo
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 57.07%)
# 2) traditional pagii (уверенность 21.32%)
# 3) traditional pagii, where the population remained about the same with almost no foreign settlers (уверенность 9.67%)
# 4) pagii (уверенность 8.21%)
# 5) pagii, where the population remained about the same with almost no foreign settlers (уверенность 3.72%)
#
#
#
# Вопрос 30: When did Rollo begin to arrive in Normandy?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.67%)
# 2) 880s (уверенность 0.21%)
# 3) the 880s (уверенность 0.08%)
# 4) in the 880s (уверенность 0.03%)
# 5) 880s, (уверенность 0.01%)
#
#
#
# Вопрос 31: What Viking groups were conquered by Rollo?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.21%)
# 2) Danes, Norwegians, Norse–Gaels, Orkney Vikings, possibly Swedes, and Anglo-Danes (уверенность 0.28%)
# 3) Swedes, and Anglo-Danes (уверенность 0.21%)
# 4) Anglo-Danes (уверенность 0.17%)
# 5) Danes, Norwegians, Norse–Gaels, Orkney Vikings (уверенность 0.13%)
#
#
#
# Вопрос 32: What was the Norman religion?
# -----------------------------------
# Ground truth: Catholicism
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 92.09%)
# 2) The Norman language was forged by the adoption of the indigenous langue d'oïl branch of Romance by a Norse-speaking ruling class (уверенность 2.71%)
# 3) The Norman language was forged by the adoption of the indigenous langue d'oïl branch of Romance (уверенность 2.19%)
# 4) unique "Norman" culture (уверенность 1.71%)
# 5) forged by the adoption of the indigenous langue d'oïl branch of Romance by a Norse-speaking ruling class, and it developed into the regional language (уверенность 1.29%)
#
#
#
# Вопрос 33: What part of France were the Normans located?
# -----------------------------------
# Ground truth: north
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) north (уверенность 80.78%)
# 2) the north (уверенность 9.51%)
# 3) north of France (уверенность 8.11%)
# 4) the north of France (уверенность 0.96%)
# 5) north of (уверенность 0.58%)
# 6)  (уверенность 0.07%)
#
#
#
# Вопрос 34: What was replace with the Norse religion?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Catholicism (уверенность 36.28%)
# 2)  (уверенность 36.10%)
# 3) Catholicism (Christianity) (уверенность 14.03%)
# 4) Catholicism (Christianity) and the Gallo-Romance language of the local people (уверенность 7.30%)
# 5) Old Norse language with Catholicism (уверенность 6.29%)
#
#
#
# Вопрос 35: What did maternal Old Norse traditions merge with?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.23%)
# 2) Frankish heritage with Old Norse traditions and customs (уверенность 0.37%)
# 3) customs (уверенность 0.18%)
# 4) Frankish (уверенность 0.12%)
# 5) Frankish heritage (уверенность 0.10%)
#
#
#
# Вопрос 36: What language replaced the Gallo-Romance language?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.46%)
# 2) Catholicism (Christianity (уверенность 0.19%)
# 3) Catholicism (уверенность 0.17%)
# 4) Christianity (уверенность 0.10%)
# 5) Catholicism (Christianity) (уверенность 0.07%)
#
#
#
# Вопрос 37: What was one of the Norman's major exports?
# -----------------------------------
# Ground truth: fighting horsemen
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) fighting horsemen (уверенность 95.62%)
# 2) fighting horsemen for more than a generation. (уверенность 1.80%)
# 3) horsemen (уверенность 1.20%)
# 4) by 1066 Normandy had been exporting fighting horsemen (уверенность 0.76%)
# 5) Normandy had been exporting fighting horsemen (уверенность 0.62%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 38: Who adopted the fuedel doctrines of the Normans?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) the rest of France (уверенность 48.72%)
# 2) France (уверенность 22.07%)
# 3) rest of France (уверенность 20.94%)
# 4) The Normans thereafter adopted the growing feudal doctrines of the rest of France (уверенность 6.57%)
# 5) the rest of France, (уверенность 1.11%)
# 6)  (уверенность 0.59%)
#
#
#
# Вопрос 39: What was one of the Norman's major imports?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) fighting horsemen (уверенность 92.37%)
# 2) horsemen (уверенность 4.89%)
# 3) Normandy had been exporting fighting horsemen (уверенность 1.18%)
# 4) by 1066 Normandy had been exporting fighting horsemen (уверенность 0.79%)
# 5) fighting horsemen for more than a generation. (уверенность 0.76%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 40: Who's arristocracy eventually served as avid Crusaders?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Italo-Norman prince Bohemund I and the Anglo-Norman king Richard the Lion-Heart (уверенность 27.28%)
# 2) Many Normans of Italy, France and England eventually served as avid Crusaders under the Italo-Norman prince Bohemund I (уверенность 19.72%)
# 3) Italo-Norman prince Bohemund I (уверенность 18.12%)
# 4) Normans of Italy, France and England eventually served as avid Crusaders under the Italo-Norman prince Bohemund I (уверенность 17.81%)
# 5) Many Normans of Italy, France and England (уверенность 17.05%)
# 6)  (уверенность 0.02%)
#
#
#
# Вопрос 41: Who was the Normans' main enemy in Italy, the Byzantine Empire and Armenia?
# -----------------------------------
# Ground truth: Seljuk Turks
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) the Pechenegs, the Bulgars, and especially the Seljuk Turks (уверенность 31.16%)
# 2) Pechenegs, the Bulgars, and especially the Seljuk Turks (уверенность 30.74%)
# 3) the Pechenegs (уверенность 13.58%)
# 4) Pechenegs (уверенность 13.40%)
# 5) the Pechenegs, the Bulgars (уверенность 11.11%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 42: Who entered Italy soon after the Byzantine Empire?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) the Normans (уверенность 55.85%)
# 2) Normans (уверенность 43.43%)
# 3) the Normans began to enter Italy, they entered the Byzantine Empire (уверенность 0.27%)
# 4) the Normans began to enter Italy (уверенность 0.24%)
# 5) Normans began to enter Italy, they entered the Byzantine Empire (уверенность 0.21%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 43: Who did the Normans fight in Italy?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Pechenegs, the Bulgars, and especially the Seljuk Turks (уверенность 35.21%)
# 2) the Pechenegs, the Bulgars, and especially the Seljuk Turks (уверенность 27.74%)
# 3) Pechenegs (уверенность 14.19%)
# 4) Pechenegs, the Bulgars (уверенность 11.68%)
# 5) the Pechenegs (уверенность 11.18%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 44: Who did the Normans encourage to come to the south?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Norman mercenaries (уверенность 93.18%)
# 2) mercenaries (уверенность 5.00%)
# 3) Norman mercenaries were first encouraged to come to the south by the Lombards to act against the Byzantines (уверенность 1.38%)
# 4) Norman mercenaries were first encouraged to come to the south by the Lombards to act against the Byzantines, (уверенность 0.35%)
# 5) mercenaries were first encouraged to come to the south by the Lombards to act against the Byzantines (уверенность 0.07%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 45: During what campaign did the Vargian and Lombard fight?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) George Maniaces (уверенность 44.10%)
# 2) Sicilian campaign of George Maniaces (уверенность 34.57%)
# 3) the Sicilian campaign of George Maniaces (уверенность 13.55%)
# 4) Sicilian (уверенность 5.01%)
# 5) George Maniaces in 1038–40 (уверенность 2.77%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 46: When did Herve serve as a Byzantine general?
# -----------------------------------
# Ground truth: 1050s
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1050s (уверенность 78.64%)
# 2) the 1050s (уверенность 15.51%)
# 3) in the 1050s (уверенность 5.63%)
# 4) 0s (уверенность 0.17%)
# 5) 1050s. (уверенность 0.05%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 47: When did Robert Crispin go up against the Turks?
# -----------------------------------
# Ground truth: 1060s
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1060s (уверенность 67.42%)
# 2) the 1060s (уверенность 23.40%)
# 3) In the 1060s (уверенность 8.54%)
# 4) 1060s, (уверенность 0.38%)
# 5) 1060s, Robert Crispin led the Normans of Edessa against the Turks (уверенность 0.26%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 48: Who ruined Roussel de Bailleul's plans for an independent state?
# -----------------------------------
# Ground truth: Alexius Komnenos
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Alexius Komnenos (уверенность 55.74%)
# 2) Byzantine general Alexius Komnenos (уверенность 26.89%)
# 3) the Byzantine general Alexius Komnenos (уверенность 9.97%)
# 4) general Alexius Komnenos (уверенность 5.05%)
# 5) Alexius Komnenos. (уверенность 1.78%)
# 6)  (уверенность 0.58%)
#
#
#
# Вопрос 49: Who was the first Byzantine mercenary to serve with the Normans?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Hervé (уверенность 99.99%)
# 2) Isaac Komnenos (уверенность 0.00%)
# 3) Isaac Komnenos. In the 1060s, Robert Crispin (уверенность 0.00%)
# 4)  (уверенность 0.00%)
# 5) Robert Crispin (уверенность 0.00%)
#
#
#
# Вопрос 50: When did Herve serve as a Norman general?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1050s (уверенность 43.99%)
# 2)  (уверенность 41.07%)
# 3) the 1050s (уверенность 9.79%)
# 4) in the 1050s (уверенность 4.85%)
# 5) 0s (уверенность 0.30%)
#
#
#
# Вопрос 51: Who ruined Alexius Komnenos plans for an independent state?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.31%)
# 2) Roussel de Bailleul (уверенность 0.29%)
# 3) Byzantine general (уверенность 0.20%)
# 4) Roussel de Bailleul even tried to carve out an independent state in Asia Minor with support from the local population (уверенность 0.15%)
# 5) the Byzantine general (уверенность 0.05%)
#
#
#
# Вопрос 52: When did Herve go up against the Turks?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1060s (уверенность 58.53%)
# 2) the 1060s (уверенность 23.23%)
# 3) In the 1060s (уверенность 15.23%)
# 4)  (уверенность 2.50%)
# 5) 1060s, Robert Crispin led the Normans of Edessa against the Turks (уверенность 0.51%)
#
#
#
# Вопрос 53: What was the name of the Norman castle?
# -----------------------------------
# Ground truth: Afranji
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Afranji (уверенность 88.74%)
# 2) Afranji, meaning "Franks." (уверенность 7.10%)
# 3)  (уверенность 2.15%)
# 4) Afranji, (уверенность 1.58%)
# 5) Oursel—led by Raimbaud. They even lent their ethnicity to the name of their castle: Afranji (уверенность 0.43%)
#
#
#
# Вопрос 54: Who was the leader when the Franks entered the Euphrates valley?
# -----------------------------------
# Ground truth: Oursel
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Oursel (уверенность 84.02%)
# 2) A Norman named Oursel (уверенность 13.38%)
# 3) Norman named Oursel (уверенность 2.23%)
# 4) A Norman (уверенность 0.31%)
# 5) Norman (уверенность 0.05%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 55: Who did the Normans team up with in Anatolia?
# -----------------------------------
# Ground truth: Turkish forces
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Armenians vassal-states of Sassoun and Taron (уверенность 32.19%)
# 2) Sassoun and Taron (уверенность 28.94%)
# 3) Armenians (уверенность 19.02%)
# 4) Turkish forces to aid in the destruction of the Armenians vassal-states of Sassoun and Taron (уверенность 9.82%)
# 5) Armenians vassal-states of Sassoun and Taron in far eastern Anatolia. Later, many took up service with the Armenian state (уверенность 8.44%)
# 6)  (уверенность 1.59%)
#
#
#
# Вопрос 56: Who joined Norman forces in the destruction of the Armenians?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Turkish forces (уверенность 70.81%)
# 2) Some Normans joined Turkish forces (уверенность 12.10%)
# 3) Normans joined Turkish forces (уверенность 10.70%)
# 4) Turkish (уверенность 4.10%)
# 5)  (уверенность 2.29%)
#
#
#
# Вопрос 57: Who did the Turks take up service with?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) the Armenian state (уверенность 45.39%)
# 2) Armenian state (уверенность 35.77%)
# 3) the Armenian (уверенность 6.91%)
# 4) the Armenian state further south in Cilicia and the Taurus Mountains (уверенность 6.33%)
# 5)  (уверенность 5.60%)
#
#
#
# Вопрос 58: What Frank led Norman forces?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Oursel (уверенность 73.39%)
# 2)  (уверенность 24.56%)
# 3) A Norman named Oursel (уверенность 1.68%)
# 4) Oursel led a force of "Franks (уверенность 0.28%)
# 5) Raimbaud (уверенность 0.09%)
#
#
#
# Вопрос 59: Where did Oursel lead the Franks?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) upper Euphrates valley in northern Syria (уверенность 42.32%)
# 2) the upper Euphrates valley in northern Syria (уверенность 21.49%)
# 3) upper Euphrates valley (уверенность 14.74%)
# 4) into the upper Euphrates valley in northern Syria (уверенность 10.78%)
# 5) northern Syria (уверенность 10.62%)
# 6)  (уверенность 0.05%)
#
#
#
# Вопрос 60: What were the origins of the Raouliii family?
# -----------------------------------
# Ground truth: Norman mercenary
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 64.09%)
# 2) Raoul (уверенность 22.05%)
# 3) an Italo-Norman named Raoul (уверенность 5.70%)
# 4) The Raoulii were descended from an Italo-Norman named Raoul (уверенность 4.76%)
# 5) Italo-Norman named Raoul (уверенность 3.40%)
#
#
#
# Вопрос 61: Where were several Norman mercenary familes originate from?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Byzantine Greece (уверенность 93.32%)
# 2) Greece (уверенность 3.92%)
# 3) Several families of Byzantine Greece (уверенность 1.35%)
# 4) Byzantine Greece were of Norman mercenary origin during the period of the Comnenian Restoration, when Byzantine emperors were seeking out western European warriors. (уверенность 0.68%)
# 5) Byzantine Greece were of Norman mercenary origin during the period of the Comnenian Restoration (уверенность 0.49%)
# 6)  (уверенность 0.23%)
#
#
#
# Вопрос 62: Who did the Normans serve under in the 10th century?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.95%)
# 2) George Maniaces (уверенность 0.05%)
# 3) George Maniaces in the Sicilian expedition of 1038 (уверенность 0.00%)
# 4) Maniaces (уверенность 0.00%)
# 5) George (уверенность 0.00%)
#
#
#
# Вопрос 63: What expedition did George Maniaces lead in the 10th century?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 100.00%)
# 2) Sicilian expedition (уверенность 0.00%)
# 3) the Sicilian expedition (уверенность 0.00%)
# 4) Sicilian (уверенность 0.00%)
# 5) the Sicilian (уверенность 0.00%)
#
#
#
# Вопрос 64: What was the name of the count of Apulia
# -----------------------------------
# Ground truth: Robert Guiscard
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Robert Guiscard (уверенность 98.65%)
# 2) Robert Guiscard, (уверенность 0.69%)
# 3) Robert Guiscard, an other Norman adventurer previously elevated to the dignity of count of Apulia (уверенность 0.32%)
# 4) Robert (уверенность 0.20%)
# 5) Guiscard (уверенность 0.14%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 65: When did Dyrrachium  fall to the Normans?
# -----------------------------------
# Ground truth: 1082
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) February 1082 (уверенность 88.90%)
# 2) 1085 (уверенность 7.40%)
# 3)  (уверенность 1.48%)
# 4) 1082 (уверенность 1.48%)
# 5) February 1082, (уверенность 0.74%)
#
#
#
# Вопрос 66: How many men were in Robert's army?
# -----------------------------------
# Ground truth: 30,000
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 30,000 (уверенность 87.71%)
# 2) 30,000 men (уверенность 11.18%)
# 3) army of 30,000 (уверенность 0.52%)
# 4) an army of 30,000 (уверенность 0.38%)
# 5) in 1081 he led an army of 30,000 (уверенность 0.21%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 67: Who ultimatly drove the Byzantines out of Europe?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Robert Guiscard (уверенность 79.61%)
# 2)  (уверенность 19.47%)
# 3) Robert Guiscard, an other Norman adventurer previously elevated to the dignity of count of Apulia (уверенность 0.88%)
# 4) pope Gregory VII (уверенность 0.03%)
# 5) Alexius I Comnenus (уверенность 0.01%)
#
#
#
# Вопрос 68: What pope opposed Roberts campaign?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 91.15%)
# 2) pope Gregory VII (уверенность 4.62%)
# 3) Gregory VII (уверенность 4.07%)
# 4) VII (уверенность 0.14%)
# 5) pope Gregory VII and acting as his vassal, Robert (уверенность 0.03%)
#
#
#
# Вопрос 69: What fell to the Normans in the 10th century?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 100.00%)
# 2) Dyrrachium (уверенность 0.00%)
# 3) Dyrrachium, Valona, and Butrint (уверенность 0.00%)
# 4) Ioannina (уверенность 0.00%)
# 5) Italy. They lost Dyrrachium, Valona, and Butrint (уверенность 0.00%)
#
#
#
# Вопрос 70: How many men did Roberts army face?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 30,000 (уверенность 78.80%)
# 2) 30,000 men (уверенность 14.06%)
# 3)  (уверенность 6.40%)
# 4) an army of 30,000 (уверенность 0.41%)
# 5) army of 30,000 (уверенность 0.33%)
#
#
#
# Вопрос 71: Where did the Normans and Byzantines sign the peace treaty?
# -----------------------------------
# Ground truth: Deabolis
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Deabolis (уверенность 46.74%)
# 2) city of Deabolis (уверенность 20.65%)
# 3) the city of Deabolis (уверенность 18.79%)
# 4) in the city of Deabolis (уверенность 12.42%)
# 5) Deabolis. (уверенность 1.40%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 72: Who was Robert's son?
# -----------------------------------
# Ground truth: Bohemond
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Bohemond (уверенность 99.41%)
# 2) Bohemond, (уверенность 0.40%)
# 3) Normans under the command of Bohemond (уверенность 0.08%)
# 4) Bohemond, Robert's son, (уверенность 0.06%)
# 5) hemond (уверенность 0.04%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 73: What river was Petrela located by?
# -----------------------------------
# Ground truth: Deabolis
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) river Deabolis (уверенность 72.79%)
# 2) Deabolis (уверенность 21.79%)
# 3) the river Deabolis (уверенность 5.00%)
# 4) river (уверенность 0.21%)
# 5) the citadel of Mili at the banks of the river Deabolis (уверенность 0.20%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 74: Who did the Normans besiege in the 11th century?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 98.50%)
# 2) Dyrrachium (уверенность 1.38%)
# 3) Arbanon passes and opened their way to Dibra (уверенность 0.06%)
# 4) Dibra (уверенность 0.04%)
# 5) Arbanon passes (уверенность 0.03%)
#
#
#
# Вопрос 75: Who did Robert lead agains Dyrrachium in 1107?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Bohemond (уверенность 33.23%)
# 2) the Normans under the command of Bohemond (уверенность 19.31%)
# 3) the Normans (уверенность 16.97%)
# 4) Normans under the command of Bohemond (уверенность 15.99%)
# 5) Normans (уверенность 14.06%)
# 6)  (уверенность 0.43%)
#
#
#
# Вопрос 76: Who was Bohemond's son?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Robert (уверенность 97.69%)
# 2) Robert's (уверенность 1.82%)
# 3) Robert's son (уверенность 0.39%)
# 4) Bohemond, Robert (уверенность 0.07%)
# 5) Normans under the command of Bohemond, Robert (уверенность 0.03%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 77: When did the Normans attack Dyrrachium?
# -----------------------------------
# Ground truth: 1185
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1185 (уверенность 97.87%)
# 2) in 1185 (уверенность 1.10%)
# 3)  (уверенность 0.46%)
# 4) 1185, (уверенность 0.43%)
# 5) 1185, when a large Norman army invaded Dyrrachium, (уверенность 0.14%)
#
#
#
# Вопрос 78: What was the naval base called?
# -----------------------------------
# Ground truth: Dyrrachium
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Dyrrachium (уверенность 91.52%)
# 2) Dyrrachium, owing to the betrayal of high Byzantine officials. Some time later, Dyrrachium (уверенность 6.93%)
# 3) Dyrrachium—one of the most important naval bases of the Adriatic (уверенность 0.70%)
# 4) Dyrrachium—one of the most important naval bases (уверенность 0.56%)
# 5)  (уверенность 0.30%)
#
#
#
# Вопрос 79: Where was Dyrrachium located?
# -----------------------------------
# Ground truth: the Adriatic
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Adriatic (уверенность 73.61%)
# 2) the Adriatic (уверенность 13.86%)
# 3)  (уверенность 6.79%)
# 4) one of the most important naval bases of the Adriatic (уверенность 5.68%)
# 5) one of the most important naval bases (уверенность 0.06%)
#
#
#
# Вопрос 80: Who attacked Dyrrachium in the 11th century?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.98%)
# 2) a large Norman army (уверенность 0.01%)
# 3) large Norman army (уверенность 0.00%)
# 4) a large Norman (уверенность 0.00%)
# 5) Norman army (уверенность 0.00%)
#
#
#
# Вопрос 81: Who betrayed the Normans?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 96.85%)
# 2) high Byzantine officials (уверенность 1.81%)
# 3) Byzantine officials (уверенность 0.54%)
# 4) Dyrrachium, owing to the betrayal of high Byzantine officials (уверенность 0.41%)
# 5) a large Norman army invaded Dyrrachium, owing to the betrayal of high Byzantine officials (уверенность 0.39%)
#
#
#
# Вопрос 82: What naval base fell to the Normans?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 98.09%)
# 2) Dyrrachium (уверенность 1.39%)
# 3) Dyrrachium, owing to the betrayal of high Byzantine officials. Some time later, Dyrrachium (уверенность 0.50%)
# 4) Dyrrachium— (уверенность 0.01%)
# 5) Dyrrachium—one of the most important naval bases of the Adriatic (уверенность 0.01%)
#
#
#
# Вопрос 83: Who did Emma Marry?
# -----------------------------------
# Ground truth: King Ethelred II
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Duke Richard II of Normandy (уверенность 62.52%)
# 2) Duke Richard II of Normandy, and King Ethelred II of England (уверенность 21.33%)
# 3) Richard II of Normandy (уверенность 8.32%)
# 4) King Ethelred II of England (уверенность 4.12%)
# 5) Duke Richard II (уверенность 3.70%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 84: Who was Emma's brother?
# -----------------------------------
# Ground truth: Duke Richard II
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Duke Richard II of Normandy (уверенность 58.69%)
# 2) Richard II of Normandy (уверенность 20.24%)
# 3) Duke Richard II (уверенность 10.12%)
# 4) Duke Richard II of Normandy, and King Ethelred II of England (уверенность 7.46%)
# 5) Richard II (уверенность 3.49%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 85: To where did Ethelred flee?
# -----------------------------------
# Ground truth: Normandy
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Normandy (уверенность 98.05%)
# 2) to Normandy (уверенность 0.82%)
# 3) Ethelred fled to Normandy (уверенность 0.58%)
# 4) Normandy in 1013, (уверенность 0.31%)
# 5) fled to Normandy (уверенность 0.24%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 86: Who kicked Ethelred out?
# -----------------------------------
# Ground truth: Sweyn Forkbeard
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Sweyn Forkbeard (уверенность 99.10%)
# 2)  (уверенность 0.74%)
# 3) Normandy in 1013, when he was forced from his kingdom by Sweyn Forkbeard (уверенность 0.16%)
# 4) King Ethelred II of England. Because of this, Ethelred fled to Normandy (уверенность 0.00%)
# 5) King Ethelred II (уверенность 0.00%)
#
#
#
# Вопрос 87: Who married Cnut the Great?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Emma (уверенность 87.94%)
# 2) Emma, sister of Duke Richard II of Normandy, and King Ethelred II of England (уверенность 6.51%)
# 3) Emma, sister of Duke Richard II of Normandy (уверенность 3.41%)
# 4) Emma, sister of Duke Richard II of Normandy, and King Ethelred II (уверенность 1.62%)
# 5)  (уверенность 0.53%)
#
#
#
# Вопрос 88: When did Richard II flee to Normandy?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1013 (уверенность 77.00%)
# 2)  (уверенность 14.85%)
# 3) 1013, when he was forced from his kingdom by Sweyn Forkbeard. His stay in Normandy (until 1016 (уверенность 4.56%)
# 4) 1013, (уверенность 1.87%)
# 5) in 1013 (уверенность 1.72%)
#
#
#
# Вопрос 89: Who's major ports were controlled by the English?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Normans were in contact with England (уверенность 32.70%)
# 2) Normans (уверенность 23.22%)
# 3)  (уверенность 16.57%)
# 4) The Normans were in contact with England (уверенность 16.08%)
# 5) The Normans (уверенность 11.42%)
#
#
#
# Вопрос 90: Who was Edward the Confessor's half-brother?
# -----------------------------------
# Ground truth: Harthacnut
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Harthacnut (уверенность 99.72%)
# 2) Hart (уверенность 0.18%)
# 3) Harthacnut, (уверенность 0.05%)
# 4) his half-brother Harthacnut (уверенность 0.04%)
# 5)  (уверенность 0.01%)
#
#
#
# Вопрос 91: When did Edward return?
# -----------------------------------
# Ground truth: 1041
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1041 (уверенность 94.99%)
# 2) in 1041 (уверенность 1.91%)
# 3) Edward the Confessor returned from his father's refuge in 1041 (уверенность 1.23%)
# 4) When finally Edward the Confessor returned from his father's refuge in 1041 (уверенность 1.15%)
# 5) 1041, (уверенность 0.72%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 92: Who did Edward make archbishop of Canterbury?
# -----------------------------------
# Ground truth: Robert of Jumièges
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Robert of Jumièges (уверенность 97.60%)
# 2) Robert of Jumièges archbishop of Canterbury (уверенность 1.88%)
# 3) Robert of Jumièges archbishop of Canterbury and made Ralph the Timid earl of Hereford (уверенность 0.33%)
# 4) Robert of Jumièges archbishop of Canterbury and made Ralph (уверенность 0.12%)
# 5) Jumièges (уверенность 0.06%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 93: When did Edward the Confessor's son return from his fathers refuge?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1041 (уверенность 94.69%)
# 2) in 1041 (уверенность 4.49%)
# 3) 1041, (уверенность 0.51%)
# 4) 1 (уверенность 0.16%)
# 5) 1041, at the invitation of his half-brother Harthacnut, (уверенность 0.14%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 94: What kind of force did Harthacnut establish?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) English cavalry (уверенность 34.41%)
# 2) English cavalry force (уверенность 33.36%)
# 3)  (уверенность 15.69%)
# 4) an English cavalry (уверенность 8.40%)
# 5) an English cavalry force (уверенность 8.14%)
#
#
#
# Вопрос 95: Who made Robert of Jumieges earl of Hereford?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 93.46%)
# 2) He appointed Robert of Jumièges archbishop of Canterbury (уверенность 3.44%)
# 3) Edward the Confessor (уверенность 1.41%)
# 4) archbishop of Canterbury (уверенность 1.39%)
# 5) Ralph the Timid earl of Hereford. He invited his brother-in-law Eustace II (уверенность 0.30%)
#
#
#
# Вопрос 96: Where did Harold II die?
# -----------------------------------
# Ground truth: Battle of Hastings
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Battle of Hastings (уверенность 63.45%)
# 2) the Battle of Hastings (уверенность 27.13%)
# 3) at the Battle of Hastings (уверенность 7.46%)
# 4) England killing King Harold II at the Battle of Hastings (уверенность 1.68%)
# 5)  (уверенность 0.28%)
#
#
#
# Вопрос 97: Who killed Harold II?
# -----------------------------------
# Ground truth: William II
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Duke William II of Normandy (уверенность 62.20%)
# 2) Duke William II (уверенность 35.50%)
# 3) Duke William (уверенность 0.90%)
# 4) Duke William II of Normandy conquered England (уверенность 0.76%)
# 5) William II of Normandy (уверенность 0.57%)
# 6)  (уверенность 0.07%)
#
#
#
# Вопрос 98: When was the Battle of Hastings?
# -----------------------------------
# Ground truth: 1066
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 1066 (уверенность 95.56%)
# 2) In 1066 (уверенность 3.51%)
# 3) 1066, Duke William II of Normandy conquered England killing King Harold II at the Battle of Hastings. (уверенность 0.27%)
# 4) 1066, Duke William II of Normandy conquered England killing King Harold II at the Battle of Hastings (уверенность 0.27%)
# 5) 1066, (уверенность 0.25%)
# 6)  (уверенность 0.14%)
#
#
#
# Вопрос 99: Who was the ruling class ahead of the Normans?
# -----------------------------------
# Ground truth: Anglo-Saxons
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Anglo-Saxons (уверенность 65.17%)
# 2) the Anglo-Saxons (уверенность 23.66%)
# 3)  (уверенность 7.96%)
# 4) The invading Normans and their descendants replaced the Anglo-Saxons (уверенность 2.01%)
# 5) Anglo-Saxons as the ruling class of England (уверенность 1.20%)
#
#
#
# Вопрос 100: When did King Harold II conquer England?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 82.40%)
# 2) 1066 (уверенность 14.82%)
# 3) 1066, Duke William II of Normandy conquered England killing King Harold II at the Battle of Hastings (уверенность 2.12%)
# 4) In 1066 (уверенность 0.48%)
# 5) Battle of Hastings (уверенность 0.18%)
#
#
#
# Вопрос 101: What battle took place in the 10th century?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 100.00%)
# 2) Battle of Hastings (уверенность 0.00%)
# 3) the Battle of Hastings (уверенность 0.00%)
# 4) 1066, Duke William II of Normandy conquered England killing King Harold II at the Battle of Hastings (уверенность 0.00%)
# 5) Hastings (уверенность 0.00%)
#
#
#
# Вопрос 102: Who replaced the Normans as the ruling class?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 72.39%)
# 2) Anglo-Saxons (уверенность 14.24%)
# 3) the Anglo-Saxons (уверенность 7.44%)
# 4) The invading Normans and their descendants replaced the Anglo-Saxons (уверенность 4.01%)
# 5) invading Normans and their descendants replaced the Anglo-Saxons (уверенность 1.92%)
#
#
#
# Вопрос 103: Who considered their land on the continent their most important holding?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 35.49%)
# 2) King of France (уверенность 19.36%)
# 3) Early Norman kings of England, as Dukes of Normandy, owed homage to the King of France (уверенность 16.96%)
# 4) the King of France (уверенность 16.48%)
# 5) Dukes of Normandy, owed homage to the King of France (уверенность 11.72%)
#
#
#
# Вопрос 104: What was the Anglo-Norman language's final form?
# -----------------------------------
# Ground truth: Modern English
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 98.68%)
# 2) Latin (уверенность 0.56%)
# 3) Latin language (уверенность 0.33%)
# 4) Middle English. It in turn evolved into Modern English (уверенность 0.23%)
# 5) Modern English (уверенность 0.20%)
#
#
#
# Вопрос 105: Who identified themselves as French during the Hundred Years War?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 100.00%)
# 2) the Norman aristocracy (уверенность 0.00%)
# 3) Norman aristocracy (уверенность 0.00%)
# 4) the Norman aristocracy often identified themselves as English (уверенность 0.00%)
# 5) Norman aristocracy often identified themselves as English (уверенность 0.00%)
#
#
#
# Вопрос 106: What was absorbed into the Anglo-Norman language?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 96.15%)
# 2) The Anglo-Norman language was eventually absorbed into the Anglo-Saxon language of their subjects (уверенность 1.37%)
# 3) Anglo-Saxon language of their subjects (уверенность 0.99%)
# 4) Anglo-Norman language was eventually absorbed into the Anglo-Saxon language of their subjects (уверенность 0.94%)
# 5) The Anglo-Norman language (уверенность 0.55%)
#
#
#
# Вопрос 107: Who made fun of the Latin language?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Geoffrey Chaucer (уверенность 95.04%)
# 2)  (уверенность 4.51%)
# 3) Chaucer (уверенность 0.20%)
# 4) some humour by Geoffrey Chaucer (уверенность 0.15%)
# 5) by Geoffrey Chaucer (уверенность 0.10%)
#
#
#
# Вопрос 108: In what year did the Norman's invade at Bannow Bay?
# -----------------------------------
# Ground truth: 1169
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# ...
# 1)  (уверенность 100.00%)
# 2) Grand coutumier de Normandie (уверенность 0.00%)
# 3) the Grand coutumier de Normandie (уверенность 0.00%)
# 4) The customary law of Normandy was developed between the 10th and 13th centuries and survives today through the legal systems of Jersey and Guernsey in the Channel Islands. (уверенность 0.00%)
# 5) Très ancien coutumier (уверенность 0.00%)
#
#
#
# Вопрос 173: What is the Norman architecture idiom?
# -----------------------------------
# Ground truth: Romanesque
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) unique Romanesque idiom (уверенность 38.11%)
# 2) a unique Romanesque idiom (уверенность 23.96%)
# 3) They spread a unique Romanesque idiom (уверенность 15.26%)
# 4) unique Romanesque (уверенность 12.33%)
# 5) Romanesque idiom (уверенность 10.19%)
# 6)  (уверенность 0.15%)
#
#
#
# Вопрос 174: What kind of arches does Norman architecture have?
# -----------------------------------
# Ground truth: rounded
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) rounded (уверенность 60.89%)
# 2) rounded arches (уверенность 38.55%)
# 3) rounded arches, (уверенность 0.24%)
# 4) rounded arches, particularly over windows and doorways, and massive proportions. (уверенность 0.21%)
# 5) Their style was characterised by rounded (уверенность 0.10%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 175: What type of arch did the Normans invent?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) rounded arches (уверенность 55.24%)
# 2) rounded (уверенность 43.71%)
# 3) arches (уверенность 0.71%)
# 4) rounded arches, particularly over windows and doorways (уверенность 0.32%)
# 5)  (уверенность 0.03%)
#
#
#
# Вопрос 176: What architecture type came after Norman in England?
# -----------------------------------
# Ground truth: Early Gothic
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Early Gothic (уверенность 60.42%)
# 2) Anglo-Saxon and precedes the Early Gothic (уверенность 22.40%)
# 3) Gothic (уверенность 7.43%)
# 4) Anglo-Saxon (уверенность 4.95%)
# 5)  (уверенность 4.80%)
#
#
#
# Вопрос 177: What architecture type came before Norman in England?
# -----------------------------------
# Ground truth: Anglo-Saxon
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Anglo-Saxon (уверенность 26.29%)
# 2)  (уверенность 25.01%)
# 3) Anglo-Saxon and precedes the Early Gothic (уверенность 20.83%)
# 4) Early Gothic (уверенность 20.73%)
# 5) the Anglo-Saxon (уверенность 7.13%)
#
#
#
# Вопрос 178: What place had the Norman Arab architectural style?
# -----------------------------------
# Ground truth: Sicily
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Kingdom of Sicily (уверенность 37.37%)
# 2) Sicily (уверенность 34.91%)
# 3) the Kingdom of Sicily (уверенность 15.54%)
# 4) within the Kingdom of Sicily (уверенность 12.00%)
# 5)  (уверенность 0.18%)
#
#
#
# Вопрос 179: What precedes the period of Anglo-Saxon architecture?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.87%)
# 2) Early Gothic (уверенность 0.07%)
# 3) the Early Gothic (уверенность 0.02%)
# 4) the period of Norman architecture immediately succeeds that of the Anglo-Saxon and precedes the Early Gothic (уверенность 0.02%)
# 5) Norman architecture immediately succeeds that of the Anglo-Saxon and precedes the Early Gothic (уверенность 0.02%)
#
#
#
# Вопрос 180: What architecture type came after Early Gothic?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 42.48%)
# 2) Norman architecture (уверенность 33.94%)
# 3) Norman (уверенность 20.18%)
# 4) Norman architecture immediately succeeds that of the Anglo-Saxon (уверенность 1.75%)
# 5) the period of Norman architecture (уверенность 1.65%)
#
#
#
# Вопрос 181: Who incorperated Islamic, LOmbard, and Byzantine building techniques in England?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.97%)
# 2) the Normans (уверенность 0.01%)
# 3) Normans (уверенность 0.01%)
# 4) Anglo-Saxon and precedes the Early Gothic. In southern Italy, the Normans (уверенность 0.00%)
# 5) Norman architecture immediately succeeds that of the Anglo-Saxon and precedes the Early Gothic. In southern Italy, the Normans (уверенность 0.00%)
#
#
#
# Вопрос 182: When did the church reform begin?
# -----------------------------------
# Ground truth: early 11th century
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) early 11th century (уверенность 58.12%)
# 2) the early 11th century (уверенность 18.03%)
# 3) 11th century (уверенность 17.80%)
# 4) in the early 11th century (уверенность 5.84%)
# 5) early 11th (уверенность 0.21%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 183: Who used the church to unify themselves?
# -----------------------------------
# Ground truth: dukes
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) the dukes (уверенность 76.86%)
# 2) dukes (уверенность 20.16%)
# 3) the dukes as a unifying force for their disparate duchy (уверенность 2.32%)
# 4) dukes as a unifying force for their disparate duchy (уверенность 0.61%)
# 5) their disparate duchy (уверенность 0.05%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 184: What kind of art did the Normans have a rich tradition of?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.98%)
# 2) visual arts (уверенность 0.01%)
# 3) visual (уверенность 0.00%)
# 4) visual arts, the Normans did not have the rich and distinctive (уверенность 0.00%)
# 5) Carolingian (уверенность 0.00%)
#
#
#
# Вопрос 185: Who began a program of church reform in the 1100s
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.95%)
# 2) the dukes (уверенность 0.03%)
# 3) dukes (уверенность 0.01%)
# 4) early 11th century the dukes (уверенность 0.00%)
# 5) in the early 11th century the dukes (уверенность 0.00%)
#
#
#
# Вопрос 186: Who was divided by the church?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.91%)
# 2) disparate duchy. The chief monasteries (уверенность 0.04%)
# 3) disparate duchy (уверенность 0.03%)
# 4) monasteries (уверенность 0.02%)
#
#
#
# Вопрос 187: Who experienced aa golden age in the 1100s and 1200s
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.98%)
# 2) Normandy (уверенность 0.02%)
# 3) Normandy experienced a golden age of illustrated manuscripts, but it was brief and the major scriptoria of Normandy (уверенность 0.00%)
# 4) Normandy. In the final decade of the 11th and first of the 12th century, Normandy (уверенность 0.00%)
# 5) dukes (уверенность 0.00%)
#
#
#
# Вопрос 188: When were the French wars of religion?
# -----------------------------------
# Ground truth: 16th century
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 16th century (уверенность 64.39%)
# 2) the 16th century (уверенность 23.54%)
# 3) in the 16th century (уверенность 10.59%)
# 4) 16th century and French Revolution in the 18th (уверенность 0.88%)
# 5) 16th (уверенность 0.61%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 189: What wars did France fight in the 1600s?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.86%)
# 2) French Wars of Religion in the 16th century and French Revolution (уверенность 0.05%)
# 3) French Wars of Religion (уверенность 0.05%)
# 4) The French Wars of Religion in the 16th century and French Revolution (уверенность 0.03%)
# 5) The French Wars of Religion (уверенность 0.02%)
#
#
#
# Вопрос 190: What revolution was fought in the 1899's?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 100.00%)
# 2) French Revolution (уверенность 0.00%)
# 3) French Revolution in the 18th (уверенность 0.00%)
# 4) French (уверенность 0.00%)
# 5) French Wars of Religion in the 16th century and French Revolution (уверенность 0.00%)
#
#
#
# Вопрос 191: What kind of needlework was used in the creation of the Bayeux Tapestry?
# -----------------------------------
# Ground truth: embroidery
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) embroidery (уверенность 91.21%)
# 2) a work of embroidery (уверенность 4.46%)
# 3) work of embroidery (уверенность 4.16%)
# 4)  (уверенность 0.17%)
# 5) Nordic traditions (уверенность 0.01%)
#
#
#
# Вопрос 192: What is Norman art's most well known piece?
# -----------------------------------
# Ground truth: Bayeux Tapestry
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Bayeux Tapestry (уверенность 64.98%)
# 2) the Bayeux Tapestry (уверенность 32.84%)
# 3) Bayeux Tapestry, (уверенность 1.02%)
# 4) Bayeux (уверенность 0.63%)
# 5) the Bayeux Tapestry, (уверенность 0.52%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 193: Who commissioned the Tapestry?
# -----------------------------------
# Ground truth: Odo
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Odo, the Bishop of Bayeux and first Earl of Kent (уверенность 73.84%)
# 2) Odo (уверенность 16.52%)
# 3) Odo, the Bishop of Bayeux (уверенность 5.51%)
# 4) Bishop of Bayeux and first Earl of Kent (уверенность 2.38%)
# 5) Odo, the Bishop of Bayeux and first Earl of Kent, (уверенность 1.75%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 194: What is the oldest work of Norman art?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 99.99%)
# 2) Bayeux Tapestry (уверенность 0.01%)
# 3) the Bayeux Tapestry (уверенность 0.00%)
# 4) Bayeux (уверенность 0.00%)
# 5) Tapestry (уверенность 0.00%)
#
#
#
# Вопрос 195: Who commissioned Danish vikings to create the Bayeux Tapestry?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Odo, the Bishop of Bayeux and first Earl of Kent (уверенность 33.64%)
# 2) Odo (уверенность 33.54%)
# 3)  (уверенность 16.71%)
# 4) Odo, the Bishop of Bayeux (уверенность 13.80%)
# 5) Odo, the Bishop of Bayeux and first Earl of Kent, employing natives from Kent (уверенность 2.32%)
#
#
#
# Вопрос 196: What is the most important type of Norman art preserved in churches?
# -----------------------------------
# Ground truth: mosaics
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) stonework or metalwork (уверенность 62.17%)
# 2) stonework (уверенность 11.77%)
# 3) as stonework or metalwork (уверенность 11.11%)
# 4) stonework or metalwork, such as capitals and baptismal fonts (уверенность 8.98%)
# 5) metalwork (уверенность 5.95%)
# 6)  (уверенность 0.03%)
#
#
#
# Вопрос 197: How has British art survived in Normandy?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 98.96%)
# 2) stonework or metalwork (уверенность 0.48%)
# 3) as stonework or metalwork (уверенность 0.36%)
# 4) stonework or metalwork, such as capitals and baptismal fonts (уверенность 0.12%)
# 5) as stonework or metalwork, such as capitals and baptismal fonts (уверенность 0.09%)
#
#
#
# Вопрос 198: What is the most common form of Norman art in churches?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) stonework or metalwork (уверенность 45.32%)
# 2) stonework or metalwork, such as capitals and baptismal fonts (уверенность 18.88%)
# 3) stonework (уверенность 11.91%)
# 4) metalwork (уверенность 9.96%)
# 5) as stonework or metalwork (уверенность 7.83%)
# 6)  (уверенность 6.10%)
#
#
#
# Вопрос 199: What was a centre of ivorywork in the 1100s?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 100.00%)
# 2) Lombard Salerno (уверенность 0.00%)
# 3) Salerno (уверенность 0.00%)
# 4) Lombard Salerno was a centre of ivorywork in the 11th century (уверенность 0.00%)
# 5) Lombard (уверенность 0.00%)
#
#
#
# Вопрос 200: In what century did important classical music developments occur in Normandy?
# -----------------------------------
# Ground truth: 11th
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) 11th (уверенность 63.18%)
# 2) 11th century (уверенность 29.41%)
# 3) the 11th (уверенность 4.83%)
# 4) the 11th century (уверенность 2.25%)
# 5) in the 11th (уверенность 0.33%)
# 6)  (уверенность 0.00%)
#
#
#
# Вопрос 201: Who were the two abbots at Fécamp Abbey?
# -----------------------------------
# Ground truth: William of Volpiano and John of Ravenna
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) William of Volpiano and John of Ravenna (уверенность 98.04%)
# 2) two Italian abbots, William of Volpiano and John of Ravenna (уверенность 0.65%)
# 3) John of Ravenna (уверенность 0.54%)
# 4) Italian abbots, William of Volpiano and John of Ravenna (уверенность 0.47%)
# 5) William of Volpiano and John of Ravenna, (уверенность 0.30%)
# 6)  (уверенность 0.01%)
#
#
#
# Вопрос 202: What developed in Normandy during the 1100s?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 100.00%)
# 2) history of classical music (уверенность 0.00%)
# 3) classical music (уверенность 0.00%)
# 4) the history of classical music (уверенность 0.00%)
# 5) several important developments in the history of classical music (уверенность 0.00%)
#
#
#
# Вопрос 203: What was Fecamp Abby the center of?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 98.34%)
# 2) musical production and education (уверенность 1.22%)
# 3) musical composition (уверенность 0.21%)
# 4) musical production (уверенность 0.17%)
# 5) education (уверенность 0.07%)
#
#
#
# Вопрос 204: Where did the monks flee to?
# -----------------------------------
# Ground truth: southern Italy
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) southern Italy (уверенность 93.11%)
# 2) Italy (уверенность 5.68%)
# 3) southern Italy, (уверенность 0.71%)
# 4) fled to southern Italy (уверенность 0.20%)
# 5) to southern Italy (уверенность 0.16%)
# 6)  (уверенность 0.13%)
#
#
#
# Вопрос 205: What monastery did the Saint-Evroul monks establish in Italy?
# -----------------------------------
# Ground truth: Latin monastery at Sant'Eufemia.
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Sant'Eufemia (уверенность 51.82%)
# 2)  (уверенность 38.71%)
# 3) a Latin monastery at Sant'Eufemia (уверенность 5.94%)
# 4) Latin monastery at Sant'Eufemia (уверенность 2.24%)
# 5) Sant'Eufemia. (уверенность 1.30%)
#
#
#
# Вопрос 206: Who patronized the monks in Italy?
# -----------------------------------
# Ground truth: Robert Guiscard
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) Robert Guiscard (уверенность 98.92%)
# 2) Robert de Grantmesnil, several monks of Saint-Evroul fled to southern Italy, where they were patronised by Robert Guiscard (уверенность 0.75%)
# 3)  (уверенность 0.33%)
# 4) Robert de Grantmesnil (уверенность 0.00%)
# 5) Norman abbot Robert de Grantmesnil (уверенность 0.00%)
#
#
#
# Вопрос 207: What tradition were the Saint-Evroul monks known for?
# -----------------------------------
# Ground truth: singing
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1) singing (уверенность 93.42%)
# 2) a tradition of singing (уверенность 2.71%)
# 3) tradition of singing (уверенность 1.99%)
# 4) singing had developed and the choir (уверенность 0.92%)
# 5) singing. (уверенность 0.57%)
# 6)  (уверенность 0.38%)
#
#
#
# Вопрос 208: Who fled from southern Italy?
# -----------------------------------
# Ground truth:
# -----------------------------------
# Ответы, предсказанные БЕРТом:
# 1)  (уверенность 73.79%)
# 2) monks of Saint-Evroul (уверенность 10.15%)
# 3) several monks of Saint-Evroul (уверенность 7.82%)
# 4) monks (уверенность 4.23%)
# 5) Saint-Evroul (уверенность 4.00%)

# %% [markdown]
# # Что еще
#
# 1. Можно сравнить метрики после 5 эпох и после 1 эпохи, сильного отличия нет, а по времени это 7 часов и 1,5 часа
#
# 2. Код выше, это разбор готового скрипта из библиотеки `transformers`
#
#         export SQUAD_DIR=/path/to/SQUAD
#
#         python run_squad.py \
#         --model_type bert \
#         --model_name_or_path bert-base-cased \
#         --do_train \
#         --do_eval \
#         --do_lower_case \
#         --train_file $SQUAD_DIR/train-v1.1.json \
#         --predict_file $SQUAD_DIR/dev-v1.1.json \
#         --per_gpu_train_batch_size 12 \
#         --learning_rate 3e-5 \
#         --num_train_epochs 2.0 \
#         --max_seq_length 384 \
#         --doc_stride 128 \
#         --output_dir /tmp/debug_squad/
#
# 3. Все это может послужить отправной точкой в более подробном освоении кода библиотеки и запуске BERT, XL трансформера, GPT-2 или любых других моделей для решения ваших задач.
